# %%
import pandas as pd

# %% [markdown]
# ### Read the Excel file using pandas :-
# ```pd.read_excel( file_path );```
#
# This will reaturn a **Dataframe** object

# %%
df = pd.read_excel("/Users/akhilsharma/GeekSpace/DATASET/Attribute DataSet.xlsx", header= None
                    , names=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J", "K", "L", "M", "N",])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#               A        B        C       D     E       F          G  \
# 0      Dress_ID    Style    Price  Rating  Size  Season   NeckLine
# 1    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 2    1212192089   Casual      Low       0     L  Summer     o-neck
# 3    1190380701  vintage     High       0     L  Automn     o-neck
# 4     966005983    Brief  Average     4.6     L  Spring     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 496   713391965   Casual      Low     4.7     M  Spring     o-neck
# 497   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 498   532874347   Casual  Average     4.7     M  Summer     v-neck
# 499   655464934   Casual  Average     4.6     L  winter  boat-neck
# 500   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#                 H          I           J           K           L  \
# 0    SleeveLength  waiseline    Material  FabricType  Decoration
# ...

# %% [markdown]
# #### ```df.head(num)``` - number of record you want to see from **START**.

# %%
df.head(5)
# Out:
#             A        B        C       D     E       F         G             H  \
# 0    Dress_ID    Style    Price  Rating  Size  Season  NeckLine  SleeveLength
# 1  1006032852     Sexy      Low     4.6     M  Summer    o-neck     sleevless
# 2  1212192089   Casual      Low       0     L  Summer    o-neck         Petal
# 3  1190380701  vintage     High       0     L  Automn    o-neck          full
# 4   966005983    Brief  Average     4.6     L  Spring    o-neck          full
#
#            I           J           K           L             M               N
# 0  waiseline    Material  FabricType  Decoration  Pattern Type  Recommendation
# 1     empire         NaN     chiffon     ruffles        animal               1
# 2    natural  microfiber         NaN     ruffles        animal               0
# 3    natural    polyster         NaN         NaN         print               0
# 4    natural        silk     chiffon  embroidary         print               1

# %% [markdown]
# #### ```df.tail(num)``` num  of record you want to see from **Bottom**.

# %%
df.tail(5)
# Out:
#              A       B        C    D     E       F          G          H  \
# 496  713391965  Casual      Low  4.7     M  Spring     o-neck       full
# 497  722565148    Sexy      Low  4.3  free  Summer     o-neck       full
# 498  532874347  Casual  Average  4.7     M  Summer     v-neck       full
# 499  655464934  Casual  Average  4.6     L  winter  boat-neck  sleevless
# 500  919930954  Casual      Low  4.4  free  Summer     v-neck      short
#
#            I         J           K         L      M  N
# 496  natural  polyster         NaN       NaN  solid  1
# 497   empire    cotton         NaN       NaN    NaN  0
# 498   empire    cotton         NaN      lace  solid  1
# 499   empire      silk  broadcloth  applique  print  1
# 500   empire    cotton    Corduroy      lace  solid  0

# %% [markdown]
# ### Read the CSV file using pandas :-
# ```pd.read_csv( file_path );```
#
# This will reaturn a **Dataframe** object

# %%
pd.read_csv("/Users/akhilsharma/GeekSpace/DATASET/haberman.csv")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv("/Users/akhilsharma/GeekSpace/DATASET/haberman.csv", header= None, names = ["Age", 'operationYr', "Nodes", "status"], )
# Out:
#      Age  operationYr  Nodes  status
# 0     30           64      1       1
# 1     30           62      3       1
# 2     30           65      0       1
# 3     31           59      2       1
# 4     31           65      4       1
# ..   ...          ...    ...     ...
# 301   75           62      1       1
# 302   76           67      0       1
# 303   77           65      3       1
# 304   78           65      1       2
# 305   83           58      2       2
#
# [306 rows x 4 columns]

# %% [markdown]
# ### Read The CSV data **seperated by ```@```**

# %%
pd.read_csv("/Users/akhilsharma/GeekSpace/DATASET/haberman1.csv", 
            header= None, names = ["Age", 'operationYr', "Nodes", "status"], sep='@')
# Out:
#      Age  operationYr  Nodes  status
# 0     30           64      1       1
# 1     30           62      3       1
# 2     30           65      0       1
# 3     31           59      2       1
# 4     31           65      4       1
# ..   ...          ...    ...     ...
# 301   75           62      1       1
# 302   76           67      0       1
# 303   77           65      3       1
# 304   78           65      1       2
# 305   83           58      2       2
#
# [306 rows x 4 columns]

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/rowanz/swagaf/master/data/test.csv')

# %%
df2.head(5)
# Out:
#    Unnamed: 0           video-id  fold-ind  \
# 0           0  anetv_pIUpJihiju0     11871
# 1           1  anetv_avGe67wRvxA     18444
# 2           2  anetv_avGe67wRvxA     18443
# 3           3  anetv_avGe67wRvxA     18441
# 4           4  anetv_avGe67wRvxA     18442
#
#                                          startphrase  \
# 0  A person shows the bottom of a large dust mop....
# 1  The camera move and we see a man next to the l...
# 2  The lady stops and adjusts the camera. the cam...
# 3  A lady wipes lipstick off her face. The lady then
# 4  The lady then lines her lips with a pencil. Th...
#
#                                                sent1                   sent2  \
# 0     A person shows the bottom of a large dust mop.        Then, the person
# 1  The camera move and we see a man next to the l...                the lady
# 2             The lady stops and adjusts the camera.  the camera move and we
# ...

# %%
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/72/_q59jbdn7sj2yp5__ym344bc0000gn/T/ipykernel_56064/2832385996.py in <module>
# ----> 1 js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
js.columns

# %%
js["user"]

# %%
df
# Out:
#               A        B        C       D     E       F          G  \
# 0      Dress_ID    Style    Price  Rating  Size  Season   NeckLine
# 1    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 2    1212192089   Casual      Low       0     L  Summer     o-neck
# 3    1190380701  vintage     High       0     L  Automn     o-neck
# 4     966005983    Brief  Average     4.6     L  Spring     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 496   713391965   Casual      Low     4.7     M  Spring     o-neck
# 497   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 498   532874347   Casual  Average     4.7     M  Summer     v-neck
# 499   655464934   Casual  Average     4.6     L  winter  boat-neck
# 500   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#                 H          I           J           K           L  \
# 0    SleeveLength  waiseline    Material  FabricType  Decoration
# ...

# %%
k = df.to_json("test.json")

# %%
pd.read_json("test.json")
# Out:
#               A        B        C       D     E       F          G  \
# 0      Dress_ID    Style    Price  Rating  Size  Season   NeckLine
# 1    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 2    1212192089   Casual      Low       0     L  Summer     o-neck
# 3    1190380701  vintage     High       0     L  Automn     o-neck
# 4     966005983    Brief  Average     4.6     L  Spring     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 496   713391965   Casual      Low     4.7     M  Spring     o-neck
# 497   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 498   532874347   Casual  Average     4.7     M  Summer     v-neck
# 499   655464934   Casual  Average     4.6     L  winter  boat-neck
# 500   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#                 H          I           J           K           L  \
# 0    SleeveLength  waiseline    Material  FabricType  Decoration
# ...

# %% [markdown]
#     Task :
#         1. Create a table attribute dataset and dress dataset
#         2. Do a bulk load for these two table for respective dataset.
#         3. Read these dataset in pandas as a dataframe.
#         4. Convert dataframe in JSON fromate
#         5. store this dataset into mongoDb
#         6. In SQL Try to perform left join operation with attribute dataset and dress dataset on column Dress_Id
#         7. Write a sql query to find out how many unique dress that we have found based on Dress_ID
#         8. Try to find out how many dress is having recommendation 0.
#         9. Try to find out total dress sale for individual dress id.
#         10.Try to find out the third highest most selling dress id.
